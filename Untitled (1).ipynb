# %% [markdown]
# База
#
# **Перенос строк**

# %%
def long_function_name(
    var_one, 
    var_two, 
    var_three,
    var_four
    ):
    print(var_one)

# %% [markdown]
# **Списки итд**

# %%
my_list = [
    1, 2, 3,
    4, 5, 6,
]
result = some_function_that_takes_arguments(
    'a', 'b', 'c',
    'd', 'e', 'f',
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 my_list = [
#       2     1, 2, 3,
#       3     4, 5, 6,
#       4 ]
# ----> 5 result = some_function_that_takes_arguments(
#       6     'a', 'b', 'c',
#       7     'd', 'e', 'f',
#       8 )
#
# NameError: name 'some_function_that_takes_arguments' is not defined

# %% [markdown]
# **Cрезы**

# %%
my_list[1:9] #Без пробелов
# Out:
# [2, 3, 4, 5, 6]

# %% [markdown]
# **Бинарные операторы математика типа**

# %%
income = (gross_wages
          + taxable_interest
          + (dividends - qualified_dividends)
          - ira_deduction
          - student_loan_interest)

# %% [markdown]
# **Импорты**

# %%
import os
import sys

# %% [markdown]
# Импорты делать в порядке:
#
#     1.Стандартные библиотеки.
#     2.Сторонние библитеки.
#     3.Локальные импорты итд.

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from mypkg.sibling import example
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 from mypkg.sibling import example
#       3 from sqlalchemy import create_engine
#
# ModuleNotFoundError: No module named 'mypkg'

# %% [markdown]
# **Использование пробелов**

# %%
spam(ham[1], {eggs: 2})
foo = (0,)
if x == 4: print(x, y); x, y = y, x

# %%
ham[1:9], ham[1:9:3], ham[:9:3], ham[1::3], ham[1:9:]
ham[lower:upper], ham[lower:upper:], ham[lower::step]
ham[lower + offset : upper + offset]

# %% [markdown]
# **Работа с операторами**

# %%
i = i + 1
submitted += 1
x = x * 2 - 1
hypot2 = x * x + y * y
c = (a + b) * (a - b)

# %% [markdown]
# **Аннотация функций**

# %%
def munge(input: AnyStr): ...
def munge() -> PosInt: ...

# %%
def complex(real, imag=0.0):
    return magic(r=real, i=imag)

# %%
def munge(sep: AnyStr = None): ...
def munge(input: AnyStr, sep: AnyStr = None, limit=1000): ...

# %%
def complex(real, imag=0.0):
    """
    Return a foobang

    Optional plotz says to frobnicate the bizbaz first.
    """
    return magic(r=real, i=imag)

# %% [markdown]
# **Try except**

# %% [markdown]
# Всегда указывать причину для except, не оставлять пустой except:

# %%
try:
    import platform_specific_module
except ImportError:
    platform_specific_module = None

# %% [markdown]
# **Что-то про with**

# %%
with conn.begin_transaction():
    do_stuff_in_transaction(conn)

# %% [markdown]
# **Работа с return**

# %% [markdown]
# Всегда возвращать None, если есть условия if/else

# %%
def foo(x):
    if x >= 0:
        return math.sqrt(x)
    else:
        return None

def bar(x):
    if x < 0:
        return None
    return math.sqrt(x)

# %% [markdown]
# **Полезные вещи**

# %%
if foo.startswith('bar'):

# %%
if isinstance(obj, int):

# %%
if not seq:
if seq:

# %% [markdown]
# **Boolean**

# %%
if greeting:
